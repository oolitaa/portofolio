# %% [markdown]
# ## Import Library

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Import Data

# %%
automobile = pd.read_csv('Automobile_data.csv')
automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ### Finding Missing Value

# %%
automobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
automobile.value_counts('normalized-losses').head()
# Out:
# normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 104     6
# Name: count, dtype: int64

# %% [markdown]
# #### Convert '?' to NaN

# %%
automobile.replace("?", np.nan, inplace=True)
automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
print(automobile.isnull().sum().where(lambda x: x > 0).dropna())
# Out:
# normalized-losses    41.0
# num-of-doors          2.0
# bore                  4.0
# stroke                4.0
# horsepower            2.0
# peak-rpm              2.0
# price                 4.0
# dtype: float64

# %% [markdown]
# ### Dealing with Missing Data
#
# 1. Drop Data
#    - drop the whole row -- Less than 5% missing values in rows
#    - drop the whole column -- More than 50% missing values in a column
# 2. Replace Data
#    - replace it by mean -- Numerical data, normally distributed
#    - replace it by frequency -- Numerical data, skewed distribution or outliers
#    - replace it based on other functions

# %% [markdown]
# #### Drop the whole row

# %%
automobile.price.isnull().sum()
# Out:
# 4

# %%
automobile.dropna(subset=["price"], axis=0, inplace=True)

# %%
# Reset Index 
automobile.reset_index(drop=True, inplace=True)
automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# #### Replace NaN by mean value

# %% [markdown]
# ##### normalized-losses

# %%
avg_normalized = automobile['normalized-losses'].astype('float').mean(axis=0) ## axis 0 for column, 1 for row
avg_normalized
# Out:
# 122.0

# %%
automobile.replace({'normalized-losses': np.nan}, avg_normalized, inplace=True)
automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ##### bore

# %%
automobile.bore.value_counts(dropna=False)
# Out:
# bore
# 3.62    23
# 3.19    20
# 3.15    15
# 2.97    12
# 3.03    10
# 3.46     9
# 3.31     8
# 3.78     8
# 3.43     8
# 3.27     7
# 2.91     7
# 3.39     6
# 3.54     6
# 3.05     6
# 3.58     6
# 3.7      5
# 3.01     5
# 3.35     4
# NaN      4
# 3.17     3
# 3.59     3
# 3.74     3
# 3.47     2
# 3.24     2
# 3.63     2
# 3.5      2
# 3.8      2
# 3.33     2
# 3.94     1
# 3.13     1
# 2.54     1
# 3.08     1
# 3.61     1
# 3.34     1
# 3.6      1
# 2.92     1
# 3.76     1
# 2.68     1
# 2.99     1
# Name: count, dtype: int64

# %%
avg_bore = automobile.bore.astype('float').mean(axis=0)
avg_bore
# Out:
# 3.330710659898477

# %%
automobile.replace({'bore':np.nan}, avg_bore, inplace=True)

# %%
automobile.bore.isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### stroke

# %%
automobile.stroke.value_counts(dropna = False)
# Out:
# stroke
# 3.4     19
# 3.23    14
# 3.15    14
# 3.03    14
# 3.39    13
# 2.64    11
# 3.29     9
# 3.35     9
# 3.46     8
# 3.27     6
# 3.19     6
# 3.41     6
# 3.07     6
# 3.58     6
# 3.5      6
# 3.64     5
# 3.52     5
# 3.86     4
# 3.54     4
# 3.47     4
# NaN      4
# 3.9      3
# 3.11     3
# 2.9      3
# 3.1      2
# 4.17     2
# 2.8      2
# 2.19     2
# 3.08     2
# 2.68     2
# 2.36     1
# 3.16     1
# 2.07     1
# 3.21     1
# 3.12     1
# 2.76     1
# 2.87     1
# Name: count, dtype: int64

# %%
avg_stroke = automobile.stroke.astype('float').mean(axis=0)
avg_stroke
# Out:
# 3.256903553299492

# %%
automobile.replace({'stroke':np.nan}, avg_bore, inplace=True)

# %%
automobile.stroke.isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### horsepower

# %%
automobile.horsepower.value_counts(dropna = False)
# Out:
# horsepower
# 68     19
# 69     10
# 70      9
# 116     9
# 110     8
# 95      7
# 88      6
# 62      6
# 101     6
# 114     6
# 160     5
# 102     5
# 145     5
# 76      5
# 82      5
# 84      5
# 97      5
# 92      4
# 123     4
# 111     4
# 86      4
# 90      3
# 152     3
# 73      3
# 207     3
# 85      3
# 182     3
# 121     3
# 112     2
# 56      2
# 94      2
# 156     2
# 52      2
# NaN     2
# 162     2
# 161     2
# 155     2
# 176     2
# 184     2
# 100     2
# 55      1
# 134     1
# 115     1
# 140     1
# 48      1
# 58      1
# 60      1
# 78      1
# 262     1
# 200     1
# 135     1
# 64      1
# 120     1
# 72      1
# 154     1
# 143     1
# 142     1
# 175     1
# 106     1
# Name: count, dtype: int64

# %%
avg_horse = automobile.horsepower.astype('float').mean(axis = 0)
avg_horse
# Out:
# 103.39698492462311

# %%
automobile.replace({'horsepower':np.nan}, avg_horse, inplace=True)

# %%
automobile.horsepower.isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### peak-rpm

# %%
automobile['peak-rpm'].value_counts(dropna= False)
# Out:
# peak-rpm
# 5500    36
# 4800    36
# 5000    27
# 5200    23
# 5400    11
# 6000     9
# 5800     7
# 5250     7
# 4500     7
# 4150     5
# 4200     5
# 4350     4
# 4750     4
# 5100     3
# 5900     3
# 4250     3
# 4400     3
# NaN      2
# 6600     2
# 4650     1
# 5600     1
# 4900     1
# 5300     1
# Name: count, dtype: int64

# %%
avg_peak = automobile['peak-rpm'].astype('float').mean(axis=0)
avg_peak
# Out:
# 5117.587939698493

# %%
automobile.replace({'peak-rpm':np.nan}, avg_peak, inplace=True)

# %%
automobile['peak-rpm'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Replace NaN by frequency

# %%
automobile['num-of-doors'].value_counts(dropna=False)#idxmax()
# Out:
# num-of-doors
# four    113
# two      86
# NaN       2
# Name: count, dtype: int64

# %%
automobile.replace({'num-of-doors': np.nan}, 'four', inplace=True)

# %%
automobile['num-of-doors'].value_counts(dropna=False)#idxmax()
# Out:
# num-of-doors
# four    115
# two      86
# Name: count, dtype: int64

# %% [markdown]
# ### Data Formating

# %%
automobile.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# Numeric to Float 
automobile[["bore", "stroke", "price", "peak-rpm"]] = automobile[["bore", "stroke", "price", "peak-rpm"]].astype(float)

# %%
automobile.dtypes.sort_values(ascending = False)
# Out:
# fuel-system           object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# horsepower            object
# normalized-losses     object
# engine-type           object
# num-of-cylinders      object
# price                float64
# compression-ratio    float64
# stroke               float64
# bore                 float64
# width                float64
# height               float64
# length               float64
# wheel-base           float64
# peak-rpm             float64
# highway-mpg            int64
# city-mpg               int64
# symboling              int64
# engine-size            int64
# curb-weight            int64
# dtype: object

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# #### Data Normalization

# %%
automobile.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  201.000000  201.000000  201.000000  201.000000  201.000000
# mean     0.840796   98.797015  174.200995   65.889055   53.766667
# std      1.254802    6.066366   12.322175    2.101471    2.447822
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.800000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.500000   66.600000   55.500000
# max      3.000000  120.900000  208.100000   72.000000   59.800000
#
#        curb-weight  engine-size        bore      stroke  compression-ratio  \
# count   201.000000   201.000000  201.000000  201.000000         201.000000
# mean   2555.666667   126.875622    3.330711    3.258372          10.164279
# std     517.296727    41.546834    0.268072    0.316216           4.004965
# ...

# %%
scaler = MinMaxScaler()
cols_to_normalize = ["curb-weight", "engine-size", "compression-ratio", "peak-rpm", "wheel-base", "length", "width", "height"]
# transformation
automobile[cols_to_normalize] = scaler.fit_transform(automobile[cols_to_normalize])
automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front    0.058309  ...     0.260377
# 1  convertible          rwd           front    0.058309  ...     0.260377
# 2    hatchback          rwd           front    0.230321  ...     0.343396
# 3        sedan          fwd           front    0.384840  ...     0.181132
# 4        sedan          4wd           front    0.373178  ...     0.283019
#
# ...

# %%
automobile['horsepower'] = automobile['horsepower'].copy().astype(int)

# %%
plt.hist(automobile['horsepower'], bins=10, edgecolor="black")

# Labels
plt.xlabel('Horsepower')
plt.ylabel('Count')
plt.title('Horsepower Bins')

plt.show()

# %% [markdown]
# #### Bining

# %%
bins = np.linspace(automobile["horsepower"].min(), automobile["horsepower"].max(), 4)  # 4 bounderies → 3 category
labels = ["Low", "Medium", "High"]

# %%
automobile["horsepower_category"] = pd.cut(automobile["horsepower"], bins=bins, labels=labels, include_lowest=True)

# %%
automobile[['horsepower', 'horsepower_category']].head()
# Out:
#    horsepower horsepower_category
# 0         111                 Low
# 1         111                 Low
# 2         154              Medium
# 3         102                 Low
# 4         115                 Low

# %%
automobile['horsepower_category'].value_counts()
# Out:
# horsepower_category
# Low       153
# Medium     43
# High        5
# Name: count, dtype: int64

# %%
plt.bar(automobile["horsepower_category"].value_counts().index, automobile["horsepower_category"].value_counts().values)

# Labels
plt.xlabel("Horsepower Category")
plt.ylabel("Count")
plt.title("Distribution of Horsepower Categories")

plt.show()

# %% [markdown]
# #### Distibution (Correlation)

# %%
automobile_numeric = automobile.select_dtypes(include=['number'])

# %%
# Calculate the correlation
corr_matrix = automobile_numeric.corr()

# %%
# Create Heatmap
plt.figure(figsize=(12, 8))  
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

plt.title("Correlation Heatmap of Numeric Columns")
plt.show()

# %%
sns.pairplot(automobile_numeric)

# %%
automobile_numeric.corr()
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.535987 -0.365404 -0.242423 -0.550160
# wheel-base         -0.535987    1.000000  0.876024  0.814507  0.590742
# length             -0.365404    0.876024  1.000000  0.857170  0.492063
# width              -0.242423    0.814507  0.857170  1.000000  0.306002
# height             -0.550160    0.590742  0.492063  0.306002  1.000000
# curb-weight        -0.233118    0.782097  0.880665  0.866201  0.307581
# engine-size        -0.110581    0.572027  0.685025  0.729436  0.074694
# bore               -0.139896    0.493203  0.608941  0.544879  0.180327
# stroke              0.000045    0.155188  0.121876  0.188293 -0.068736
# compression-ratio  -0.182196    0.250313  0.159733  0.189867  0.259737
# horsepower          0.075776    0.371297  0.579688  0.614972 -0.086901
# peak-rpm            0.279719   -0.360233 -0.286035 -0.245852 -0.309913
# ...
